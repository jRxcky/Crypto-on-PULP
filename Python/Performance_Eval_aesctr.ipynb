# %%
import matplotlib.pyplot as plt

numbers_list = [512, 1, 2, 4, 8, 16, 32]
payload_sizes = [512, 1024, 2048, 4096, 8192, 16384, 32768]

def calculate_cpi(file_path, payload_size):
    # Initialize variables to store cycle numbers
    first_cycle = None
    last_cycle = None
    instruction_count = 0

    # Track cluster entry indices
    first_cluster_index = None
    last_cluster_index = None
    
    # Track dma wait control
    dma_wait_cycle = None
    cluster_or_dispatch_cycle = None
    total_dma_to_cluster_cycles = 0

    # Track dma control
    dma_cycle = None
    dma_stop_cycle = None

    # Read the contents of the file
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Identify the first and last cluster_entry
    for i, line in enumerate(lines):
        if "cluster_entry" in line:
            if first_cluster_index is None:
                first_cluster_index = i
            last_cluster_index = i

    # Loop through each line within the range of first and last cluster_entry
    if first_cluster_index is not None and last_cluster_index is not None:
        for line in lines[first_cluster_index:last_cluster_index+1]:
            parts = line.split(':')  # Split line by colon ':'
            if len(parts) >= 2:
                cycle_str = parts[1].strip()  # Extract the cycle number string
                try:
                    cycle_number = int(cycle_str)  # Convert the string to an integer
                    if first_cycle is None:
                        first_cycle = cycle_number
                    last_cycle = cycle_number
                    instruction_count += 1

                    # Check for "pi_cl_dma_cmd_wait"
                    if "pi_cl_dma_cmd_wait" in line and dma_wait_cycle is None:
                        dma_wait_cycle = cycle_number
                    # Check for "cluster_entry" or "eu_dispatch_team_config"
                    if ("cluster_entry" in line or "eu_dispatch_team_config" in line) and dma_wait_cycle is not None:
                        cluster_or_dispatch_cycle = cycle_number
                        total_dma_to_cluster_cycles += cluster_or_dispatch_cycle - dma_wait_cycle
                        dma_wait_cycle = None  # Reset for next pair

                    # Check for "pi_cl_dma_cmd"
                    if "pi_cl_dma_cmd:" in line and dma_cycle is None:
                        #print(f"dma {cycle_number}: {line.strip()}")  # Log the line for verification
                        dma_cycle = cycle_number
                    
                    # Check for "cluster_entry" or "eu_dispatch_team_config"
                    if ("cluster_entry" in line or "eu_dispatch_team_config" in line or "pi_cl_dma_cmd_wait" in line) and dma_cycle is not None:
                        #print(f"finish dma {cycle_number}: {line.strip()}")  # Log the line for verification
                        dma_stop_cycle = cycle_number
                        total_dma_to_cluster_cycles += dma_stop_cycle - dma_cycle
                        dma_cycle = None  # Reset for next pair

                        
                except ValueError:
                    continue  # Skip lines that cannot be converted to integers

    if first_cycle is not None and last_cycle is not None:
        total_cycles = last_cycle - first_cycle
        cpi = total_cycles / instruction_count if instruction_count > 0 else 0
        ipc = instruction_count / total_cycles if total_cycles > 0 else 0
        cycles_per_byte = total_cycles / payload_size if payload_size > 0 else 0
        return total_cycles, instruction_count, cpi, ipc, cycles_per_byte, total_dma_to_cluster_cycles
    else:
        return None, None, None, None, None

# %%
clock_cycles_list = []
instruction_count_list = []
cpi_list = []
ipc_list = []
cycles_per_byte_list = []
total_dma_to_cluster_cycles_list = []

for i in range(1, 9):
    for payload_size, number in zip(payload_sizes, numbers_list):
        file_path = f"output_files_aes256ctr/{number}_{i}cores.txt"
        total_cycles, instruction_count, cpi, ipc, cycles_per_byte, total_dma_to_cluster_cycles = calculate_cpi(file_path, payload_size)
        if total_cycles is not None and instruction_count is not None and cpi is not None and ipc is not None and cycles_per_byte is not None:
            print(f"Results for {file_path}:")
            print("Total cycles elapsed:", total_cycles)
            print("Total instructions executed:", instruction_count)
            print("CPI:", cpi)
            print("IPC:", ipc)
            print("Cycles per byte:", cycles_per_byte)
            print("DMA control cycles:", total_dma_to_cluster_cycles)
            print()
            clock_cycles_list.append(total_cycles)
            instruction_count_list.append(instruction_count)
            cpi_list.append(cpi)
            ipc_list.append(ipc)
            cycles_per_byte_list.append(cycles_per_byte)
            total_dma_to_cluster_cycles_list.append(total_dma_to_cluster_cycles)
        else:
            print(f"Error: Cycle numbers not found in the file {file_path}.")
# Out:
# Results for output_files_aes256ctr/512_1cores.txt:
# Total cycles elapsed: 396130
# Total instructions executed: 209986
# CPI: 1.8864590972731516
# IPC: 0.53009365612299
# Cycles per byte: 773.69140625
# DMA control cycles: 5126
#
# Results for output_files_aes256ctr/1_1cores.txt:
# Total cycles elapsed: 777316
# Total instructions executed: 413410
# CPI: 1.8802544689291503
# IPC: 0.5318429055879462
# Cycles per byte: 759.09765625
# DMA control cycles: 9714
#
# Results for output_files_aes256ctr/2_1cores.txt:
# Total cycles elapsed: 1539649
# Total instructions executed: 820259
# CPI: 1.8770278655887958
# IPC: 0.5327571414004101
# Cycles per byte: 751.78173828125
# DMA control cycles: 18888
#
# Results for output_files_aes256ctr/4_1cores.txt:
# Total cycles elapsed: 3064093
# Total instructions executed: 1633962
# CPI: 1.8752535248677753
# IPC: 0.5332612293425819
# Cycles per byte: 748.069580078125
# DMA control cycles: 37360
#
# Results for output_files_aes256ctr/8_1cores.txt:
# Total cycles elapsed: 6112970
# Total instructions executed: 3261361
# CPI: 1.8743616545362503
# IPC: 0.5335149689921593
# Cycles per byte: 746.212158203125
# DMA control cycles: 74048
#
# Results for output_files_aes256ctr/16_1cores.txt:
# Total cycles elapsed: 12210746
# Total instructions executed: 6516159
# CPI: 1.8739177481703562
# IPC: 0.5336413516422338
# Cycles per byte: 745.2847900390625
# DMA control cycles: 147468
#
# Results for output_files_aes256ctr/32_1cores.txt:
# Total cycles elapsed: 24406528
# Total instructions executed: 13025755
# CPI: 1.8737131168212515
# IPC: 0.5336996315084227
# Cycles per byte: 744.828125
# DMA control cycles: 294298
#
# Results for output_files_aes256ctr/512_2cores.txt:
# Total cycles elapsed: 213482
# Total instructions executed: 214519
# CPI: 0.9951659293582387
# IPC: 1.004857552393176
# Cycles per byte: 416.95703125
# DMA control cycles: 3112
#
# Results for output_files_aes256ctr/1_2cores.txt:
# Total cycles elapsed: 410937
# Total instructions executed: 416247
# CPI: 0.9872431513019914
# IPC: 1.012921688726009
# Cycles per byte: 401.3056640625
# DMA control cycles: 5464
#
# Results for output_files_aes256ctr/2_2cores.txt:
# Total cycles elapsed: 806260
# Total instructions executed: 819704
# CPI: 0.9835989576725257
# IPC: 1.0166745218663955
# Cycles per byte: 393.681640625
# DMA control cycles: 10256
#
# Results for output_files_aes256ctr/4_2cores.txt:
# Total cycles elapsed: 1597247
# Total instructions executed: 1626623
# CPI: 0.9819404988125706
# IPC: 1.0183916451243922
# Cycles per byte: 389.952880859375
# DMA control cycles: 19228
#
# Results for output_files_aes256ctr/8_2cores.txt:
# Total cycles elapsed: 3178411
# Total instructions executed: 3240454
# CPI: 0.980853608784448
# IPC: 1.0195201312857274
# Cycles per byte: 387.9896240234375
# DMA control cycles: 37912
#
# Results for output_files_aes256ctr/16_2cores.txt:
# Total cycles elapsed: 6340086
# Total instructions executed: 6468116
# CPI: 0.9802059827003721
# IPC: 1.0201937323878572
# Cycles per byte: 386.9681396484375
# DMA control cycles: 75264
#
# Results for output_files_aes256ctr/32_2cores.txt:
# Total cycles elapsed: 12664144
# Total instructions executed: 12923440
# CPI: 0.9799359922745028
# IPC: 1.0204748145630689
# Cycles per byte: 386.47900390625
# DMA control cycles: 149942
#
# Results for output_files_aes256ctr/512_3cores.txt:
# Total cycles elapsed: 154082
# Total instructions executed: 226816
# CPI: 0.679325973476298
# IPC: 1.472047351410288
# Cycles per byte: 300.94140625
# DMA control cycles: 2200
#
# Results for output_files_aes256ctr/1_3cores.txt:
# Total cycles elapsed: 292917
# Total instructions executed: 434605
# CPI: 0.673984422636647
# IPC: 1.4837138165418873
# Cycles per byte: 286.0517578125
# DMA control cycles: 3872
#
# Results for output_files_aes256ctr/2_3cores.txt:
# Total cycles elapsed: 557082
# Total instructions executed: 831201
# CPI: 0.6702133418992519
# IPC: 1.4920622098721552
# Cycles per byte: 272.0126953125
# DMA control cycles: 6994
#
# Results for output_files_aes256ctr/4_3cores.txt:
# Total cycles elapsed: 1096756
# Total instructions executed: 1643389
# CPI: 0.6673745534380479
# IPC: 1.4984089441954271
# Cycles per byte: 267.7626953125
# DMA control cycles: 13202
#
# Results for output_files_aes256ctr/8_3cores.txt:
# Total cycles elapsed: 2166314
# Total instructions executed: 3248759
# CPI: 0.6668127737391416
# IPC: 1.4996713311182035
# Cycles per byte: 264.442626953125
# DMA control cycles: 25642
#
# Results for output_files_aes256ctr/16_3cores.txt:
# Total cycles elapsed: 4315911
# Total instructions executed: 6478506
# CPI: 0.6661892417788916
# IPC: 1.5010749758278148
# Cycles per byte: 263.42230224609375
# DMA control cycles: 50700
#
# Results for output_files_aes256ctr/32_3cores.txt:
# Total cycles elapsed: 8601861
# Total instructions executed: 12918993
# CPI: 0.6658306107914138
# IPC: 1.501883487770844
# Cycles per byte: 262.5079650878906
# DMA control cycles: 100726
#
# Results for output_files_aes256ctr/512_4cores.txt:
# Total cycles elapsed: 118458
# Total instructions executed: 226416
# CPI: 0.523187407250371
# IPC: 1.9113609887048575
# Cycles per byte: 231.36328125
# DMA control cycles: 1770
#
# Results for output_files_aes256ctr/1_4cores.txt:
# Total cycles elapsed: 221627
# Total instructions executed: 427552
# CPI: 0.5183626786917147
# IPC: 1.9291512315737704
# Cycles per byte: 216.4326171875
# DMA control cycles: 2920
#
# Results for output_files_aes256ctr/2_4cores.txt:
# Total cycles elapsed: 427244
# Total instructions executed: 829825
# CPI: 0.5148603621245443
# IPC: 1.942274203967756
# Cycles per byte: 208.615234375
# DMA control cycles: 5250
#
# Results for output_files_aes256ctr/4_4cores.txt:
# Total cycles elapsed: 838856
# Total instructions executed: 1634392
# CPI: 0.5132526346188675
# IPC: 1.948358240270082
# Cycles per byte: 204.798828125
# DMA control cycles: 9978
#
# Results for output_files_aes256ctr/8_4cores.txt:
# Total cycles elapsed: 1664344
# Total instructions executed: 3243503
# CPI: 0.5131316357654054
# IPC: 1.9488176723081285
# Cycles per byte: 203.1669921875
# DMA control cycles: 19338
#
# Results for output_files_aes256ctr/16_4cores.txt:
# Total cycles elapsed: 3308233
# Total instructions executed: 6461725
# CPI: 0.511973660284212
# IPC: 1.9532254832111282
# Cycles per byte: 201.91851806640625
# DMA control cycles: 38042
#
# Results for output_files_aes256ctr/32_4cores.txt:
# Total cycles elapsed: 6602837
# Total instructions executed: 12898169
# CPI: 0.5119204904199969
# IPC: 1.9534283520856262
# Cycles per byte: 201.50259399414062
# DMA control cycles: 75494
#
# Results for output_files_aes256ctr/512_5cores.txt:
# Total cycles elapsed: 108408
# Total instructions executed: 251681
# CPI: 0.4307357329317668
# IPC: 2.3216091063390154
# Cycles per byte: 211.734375
# DMA control cycles: 1570
#
# Results for output_files_aes256ctr/1_5cores.txt:
# Total cycles elapsed: 187013
# Total instructions executed: 440227
# CPI: 0.42481038191660214
# IPC: 2.3539914337505947
# Cycles per byte: 182.6298828125
# DMA control cycles: 2442
#
# Results for output_files_aes256ctr/2_5cores.txt:
# Total cycles elapsed: 357193
# Total instructions executed: 848915
# CPI: 0.4207641518879982
# IPC: 2.3766283213836776
# Cycles per byte: 174.41064453125
# DMA control cycles: 4308
#
# Results for output_files_aes256ctr/4_5cores.txt:
# Total cycles elapsed: 697681
# Total instructions executed: 1666304
# CPI: 0.41869970905669074
# IPC: 2.3883465365976715
# Cycles per byte: 170.332275390625
# DMA control cycles: 8116
#
# Results for output_files_aes256ctr/8_5cores.txt:
# Total cycles elapsed: 1365390
# Total instructions executed: 3269464
# CPI: 0.41761891245782184
# IPC: 2.394527570877185
# Cycles per byte: 166.673583984375
# DMA control cycles: 15500
#
# Results for output_files_aes256ctr/16_5cores.txt:
# Total cycles elapsed: 2703130
# Total instructions executed: 6475840
# CPI: 0.41741766319118445
# IPC: 2.395682042669054
# Cycles per byte: 164.9859619140625
# DMA control cycles: 30274
#
# Results for output_files_aes256ctr/32_5cores.txt:
# Total cycles elapsed: 5389562
# Total instructions executed: 12920131
# CPI: 0.41714453204847535
# IPC: 2.3972506485684737
# Cycles per byte: 164.47637939453125
# DMA control cycles: 59950
#
# Results for output_files_aes256ctr/512_6cores.txt:
# Total cycles elapsed: 96818
# Total instructions executed: 264363
# CPI: 0.36623128047419645
# IPC: 2.7305149868826044
# Cycles per byte: 189.09765625
# DMA control cycles: 1462
#
# Results for output_files_aes256ctr/1_6cores.txt:
# Total cycles elapsed: 163455
# Total instructions executed: 452979
# CPI: 0.36084454246223335
# IPC: 2.7712764981187483
# Cycles per byte: 159.6240234375
# DMA control cycles: 2200
#
# Results for output_files_aes256ctr/2_6cores.txt:
# Total cycles elapsed: 311640
# Total instructions executed: 868140
# CPI: 0.358974358974359
# IPC: 2.7857142857142856
# Cycles per byte: 152.16796875
# DMA control cycles: 3764
#
# Results for output_files_aes256ctr/4_6cores.txt:
# Total cycles elapsed: 590574
# Total instructions executed: 1660571
# CPI: 0.3556451365223167
# IPC: 2.8117915790400527
# Cycles per byte: 144.18310546875
# DMA control cycles: 6554
#
# Results for output_files_aes256ctr/8_6cores.txt:
# Total cycles elapsed: 1165645
# Total instructions executed: 3283290
# CPI: 0.35502346731479706
# IPC: 2.8167152091760355
# Cycles per byte: 142.2906494140625
# DMA control cycles: 12572
#
# Results for output_files_aes256ctr/16_6cores.txt:
# Total cycles elapsed: 2303734
# Total instructions executed: 6490848
# CPI: 0.35492034322788024
# IPC: 2.817533621503177
# Cycles per byte: 140.6087646484375
# DMA control cycles: 24496
#
# Results for output_files_aes256ctr/32_6cores.txt:
# Total cycles elapsed: 4594428
# Total instructions executed: 12943844
# CPI: 0.3549508167743678
# IPC: 2.8172917281541903
# Cycles per byte: 140.2108154296875
# DMA control cycles: 48508
#
# Results for output_files_aes256ctr/512_7cores.txt:
# Total cycles elapsed: 84631
# Total instructions executed: 264373
# CPI: 0.3201196793923737
# IPC: 3.123831692878496
# Cycles per byte: 165.294921875
# DMA control cycles: 1424
#
# Results for output_files_aes256ctr/1_7cores.txt:
# Total cycles elapsed: 153554
# Total instructions executed: 484649
# CPI: 0.3168354829990364
# IPC: 3.1562121468669004
# Cycles per byte: 149.955078125
# DMA control cycles: 2176
#
# Results for output_files_aes256ctr/2_7cores.txt:
# Total cycles elapsed: 275627
# Total instructions executed: 880942
# CPI: 0.3128775787736309
# IPC: 3.196138259314218
# Cycles per byte: 134.58349609375
# DMA control cycles: 3538
#
# Results for output_files_aes256ctr/4_7cores.txt:
# Total cycles elapsed: 523110
# Total instructions executed: 1673573
# CPI: 0.31257076924639676
# IPC: 3.199275486991264
# Cycles per byte: 127.71240234375
# DMA control cycles: 6026
#
# Results for output_files_aes256ctr/8_7cores.txt:
# Total cycles elapsed: 1029971
# Total instructions executed: 3303016
# CPI: 0.3118274328674157
# IPC: 3.206901941899335
# Cycles per byte: 125.7288818359375
# DMA control cycles: 11376
#
# Results for output_files_aes256ctr/16_7cores.txt:
# Total cycles elapsed: 2025087
# Total instructions executed: 6517658
# CPI: 0.31070777263857663
# IPC: 3.21845826870648
# Cycles per byte: 123.60150146484375
# DMA control cycles: 21916
#
# Results for output_files_aes256ctr/32_7cores.txt:
# Total cycles elapsed: 4017492
# Total instructions executed: 12947006
# CPI: 0.3103027835161272
# IPC: 3.222658813010704
# Cycles per byte: 122.6041259765625
# DMA control cycles: 43032
#
# Results for output_files_aes256ctr/512_8cores.txt:
# Total cycles elapsed: 71385
# Total instructions executed: 251747
# CPI: 0.28355849324917476
# IPC: 3.526609231631295
# Cycles per byte: 139.423828125
# DMA control cycles: 1256
#
# Results for output_files_aes256ctr/1_8cores.txt:
# Total cycles elapsed: 127261
# Total instructions executed: 453107
# CPI: 0.2808630191102764
# IPC: 3.5604544990216955
# Cycles per byte: 124.2783203125
# DMA control cycles: 1834
#
# Results for output_files_aes256ctr/2_8cores.txt:
# Total cycles elapsed: 237837
# Total instructions executed: 855828
# CPI: 0.2779028028996481
# IPC: 3.598380403385512
# Cycles per byte: 116.13134765625
# DMA control cycles: 3044
#
# Results for output_files_aes256ctr/4_8cores.txt:
# Total cycles elapsed: 460247
# Total instructions executed: 1661291
# CPI: 0.2770417705266567
# IPC: 3.6095639949853013
# Cycles per byte: 112.364990234375
# DMA control cycles: 5106
#
# Results for output_files_aes256ctr/8_8cores.txt:
# Total cycles elapsed: 904311
# Total instructions executed: 3272194
# CPI: 0.2763622816984568
# IPC: 3.6184387893103147
# Cycles per byte: 110.3895263671875
# DMA control cycles: 9706
#
# Results for output_files_aes256ctr/16_8cores.txt:
# Total cycles elapsed: 1793103
# Total instructions executed: 6494000
# CPI: 0.27611687711733907
# IPC: 3.621654751567534
# Cycles per byte: 109.44232177734375
# DMA control cycles: 18914
#
# Results for output_files_aes256ctr/32_8cores.txt:
# Total cycles elapsed: 3569348
# Total instructions executed: 12937612
# CPI: 0.27588924447571933
# IPC: 3.624642931986458
# Cycles per byte: 108.9278564453125
# DMA control cycles: 37402

# %%
# Size labels
sizes = ['512B', '1K', '2K', '4K', '8K', '16K', '32K']

# Function to plot the data
def plot_combined_data(clock_cycles, instruction_counts, cpis, ipcs, cpb, dma_cycles):
    # Plot clock cycles
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, clock_cycles[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Clock Cycles based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('Clock Cycles')
    plt.legend()
    plt.grid(True)
    plt.savefig('clock_cycles.png')
    plt.show()
    
    # Plot instruction counts
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, instruction_counts[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Instruction Count based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('Instruction Count')
    plt.legend()
    plt.grid(True)
    plt.savefig('instruction_count.png')
    plt.show()
    
    # Plot CPI
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, cpis[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('CPI based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('CPI')
    plt.legend()
    plt.grid(True)
    plt.savefig('cpi.png')
    plt.show()
    
    # Plot IPC
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, ipcs[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('IPC based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('IPC')
    plt.legend()
    plt.grid(True)
    plt.savefig('ipc.png')
    plt.show()

    # Plot cycles per byte
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, cpb[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Cycles per Byte based on Payload Size')
    plt.xlabel('Payload Size (Bytes)')
    plt.ylabel('Cycles per Byte')
    plt.legend()
    plt.grid(True)
    plt.savefig('cycles_per_byte.png')
    plt.show()

    # Plot DMA cycles as a percentage of total cycles
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        dma_percentages = [100 * dma / total if total > 0 else 0 for dma, total in zip(dma_cycles[start_index:end_index], clock_cycles[start_index:end_index])]
        plt.plot(sizes, dma_percentages, marker='o', label=f'{core + 1} Core')
    plt.title('DMA Cycles as a Percentage of Total Cycles')
    plt.xlabel('Payload Size')
    plt.ylabel('DMA Cycles (%)')
    plt.legend()
    plt.grid(True)
    plt.savefig('dma_cycles.png')
    plt.show()

# %%
# Function to plot the speedup
def plot_speedup(clock_cycles):
    single_core_cycles = clock_cycles[:len(sizes)]
    
    plt.figure(figsize=(10, 6))
    for core in range(1, 8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        
        multi_core_cycles = clock_cycles[start_index:end_index]
        speedup = [single_core_cycles[i] / multi_core_cycles[i] for i in range(len(sizes))]
        
        plt.plot(sizes, speedup, marker='o', label=f'{core + 1} Cores')
    
    plt.title('Speedup Compared to 1 Core')
    plt.xlabel('Payload Size')
    plt.ylabel('Speedup')
    plt.legend()
    plt.grid(True)
    plt.savefig('speedup.png')
    plt.show()

# %%
# Function to plot the efficiency
def plot_efficiency(clock_cycles):
    single_core_cycles = clock_cycles[:len(sizes)]
    
    plt.figure(figsize=(10, 6))
    for core in range(1, 8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        
        multi_core_cycles = clock_cycles[start_index:end_index]
        efficiency = [single_core_cycles[i] / (multi_core_cycles[i] * (core + 1)) for i in range(len(sizes))]
        
        plt.plot(sizes, efficiency, marker='o', label=f'{core + 1} Cores')
    
    plt.title('Efficiency Compared to 1 Core')
    plt.xlabel('Payload Size')
    plt.ylabel('Efficiency')
    plt.legend()
    plt.grid(True)
    plt.savefig('efficiency.png')
    plt.show()

# %%
# Plot combined data
plot_combined_data(clock_cycles_list, instruction_count_list, cpi_list, ipc_list, cycles_per_byte_list, total_dma_to_cluster_cycles_list)
# Plot speedup
plot_speedup(clock_cycles_list)
# Plot efficiency
plot_efficiency(clock_cycles_list)
