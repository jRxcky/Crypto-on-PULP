# %%
import matplotlib.pyplot as plt

numbers_list = [512, 1, 2, 4, 8, 16, 32]
payload_sizes = [512, 1024, 2048, 4096, 8192, 16384, 32768]

def calculate_cpi(file_path, payload_size):
    # Initialize variables to store cycle numbers
    first_cycle = None
    last_cycle = None
    instruction_count = 0

    # Track cluster entry indices
    first_cluster_index = None
    last_cluster_index = None
    
    # Track dma wait control
    dma_wait_cycle = None
    cluster_or_dispatch_cycle = None
    total_dma_to_cluster_cycles = 0

    # Track dma control
    dma_cycle = None
    dma_stop_cycle = None

    # Read the contents of the file
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Identify the first and last cluster_entry
    for i, line in enumerate(lines):
        if "cluster_entry" in line:
            if first_cluster_index is None:
                first_cluster_index = i
            last_cluster_index = i

    # Loop through each line within the range of first and last cluster_entry
    if first_cluster_index is not None and last_cluster_index is not None:
        for line in lines[first_cluster_index:last_cluster_index+1]:
            parts = line.split(':')  # Split line by colon ':'
            if len(parts) >= 2:
                cycle_str = parts[1].strip()  # Extract the cycle number string
                try:
                    cycle_number = int(cycle_str)  # Convert the string to an integer
                    if first_cycle is None:
                        first_cycle = cycle_number
                    last_cycle = cycle_number
                    instruction_count += 1

                    # Check for "pi_cl_dma_cmd_wait"
                    if "pi_cl_dma_cmd_wait" in line and dma_wait_cycle is None:
                        dma_wait_cycle = cycle_number
                    # Check for "cluster_entry" or "eu_dispatch_team_config"
                    if ("cluster_entry" in line or "eu_dispatch_team_config" in line) and dma_wait_cycle is not None:
                        cluster_or_dispatch_cycle = cycle_number
                        total_dma_to_cluster_cycles += cluster_or_dispatch_cycle - dma_wait_cycle
                        dma_wait_cycle = None  # Reset for next pair

                    # Check for "pi_cl_dma_cmd"
                    if "pi_cl_dma_cmd:" in line and dma_cycle is None:
                        #print(f"dma {cycle_number}: {line.strip()}")  # Log the line for verification
                        dma_cycle = cycle_number
                    
                    # Check for "cluster_entry" or "eu_dispatch_team_config"
                    if ("cluster_entry" in line or "eu_dispatch_team_config" in line or "pi_cl_dma_cmd_wait" in line) and dma_cycle is not None:
                        #print(f"finish dma {cycle_number}: {line.strip()}")  # Log the line for verification
                        dma_stop_cycle = cycle_number
                        total_dma_to_cluster_cycles += dma_stop_cycle - dma_cycle
                        dma_cycle = None  # Reset for next pair

                        
                except ValueError:
                    continue  # Skip lines that cannot be converted to integers

    if first_cycle is not None and last_cycle is not None:
        total_cycles = last_cycle - first_cycle
        cpi = total_cycles / instruction_count if instruction_count > 0 else 0
        ipc = instruction_count / total_cycles if total_cycles > 0 else 0
        cycles_per_byte = total_cycles / payload_size if payload_size > 0 else 0
        return total_cycles, instruction_count, cpi, ipc, cycles_per_byte, total_dma_to_cluster_cycles
    else:
        return None, None, None, None, None

# %%
clock_cycles_list = []
instruction_count_list = []
cpi_list = []
ipc_list = []
cycles_per_byte_list = []
total_dma_to_cluster_cycles_list = []

for i in range(1, 9):
    for payload_size, number in zip(payload_sizes, numbers_list):
        file_path = f"output_files_c20p1305/{number}_{i}cores.txt"
        total_cycles, instruction_count, cpi, ipc, cycles_per_byte, total_dma_to_cluster_cycles = calculate_cpi(file_path, payload_size)
        if total_cycles is not None and instruction_count is not None and cpi is not None and ipc is not None and cycles_per_byte is not None:
            print(f"Results for {file_path}:")
            print("Total cycles elapsed:", total_cycles)
            print("Total instructions executed:", instruction_count)
            print("CPI:", cpi)
            print("IPC:", ipc)
            print("Cycles per byte:", cycles_per_byte)
            print("DMA control cycles:", total_dma_to_cluster_cycles)
            print()
            clock_cycles_list.append(total_cycles)
            instruction_count_list.append(instruction_count)
            cpi_list.append(cpi)
            ipc_list.append(ipc)
            cycles_per_byte_list.append(cycles_per_byte)
            total_dma_to_cluster_cycles_list.append(total_dma_to_cluster_cycles)
        else:
            print(f"Error: Cycle numbers not found in the file {file_path}.")
# Out:
# Results for output_files_c20p1305/512_1cores.txt:
# Total cycles elapsed: 49805
# Total instructions executed: 27014
# CPI: 1.8436736506996372
# IPC: 0.5423953418331493
# Cycles per byte: 97.275390625
# DMA control cycles: 1706
#
# Results for output_files_c20p1305/1_1cores.txt:
# Total cycles elapsed: 86995
# Total instructions executed: 49726
# CPI: 1.7494871898001045
# IPC: 0.5715960687395827
# Cycles per byte: 84.9560546875
# DMA control cycles: 2852
#
# Results for output_files_c20p1305/2_1cores.txt:
# Total cycles elapsed: 162012
# Total instructions executed: 95151
# CPI: 1.702683103698332
# IPC: 0.5873083475298126
# Cycles per byte: 79.107421875
# DMA control cycles: 5216
#
# Results for output_files_c20p1305/4_1cores.txt:
# Total cycles elapsed: 310110
# Total instructions executed: 185998
# CPI: 1.66727599221497
# IPC: 0.599780722969269
# Cycles per byte: 75.71044921875
# DMA control cycles: 9562
#
# Results for output_files_c20p1305/8_1cores.txt:
# Total cycles elapsed: 607884
# Total instructions executed: 367694
# CPI: 1.653233395160106
# IPC: 0.6048752722558909
# Cycles per byte: 74.20458984375
# DMA control cycles: 18586
#
# Results for output_files_c20p1305/16_1cores.txt:
# Total cycles elapsed: 1203369
# Total instructions executed: 731085
# CPI: 1.6460042265947188
# IPC: 0.6075318543189994
# Cycles per byte: 73.44781494140625
# DMA control cycles: 36638
#
# Results for output_files_c20p1305/32_1cores.txt:
# Total cycles elapsed: 2394286
# Total instructions executed: 1457868
# CPI: 1.6423201551855175
# IPC: 0.6088946767428787
# Cycles per byte: 73.06781005859375
# DMA control cycles: 72734
#
# Results for output_files_c20p1305/512_2cores.txt:
# Total cycles elapsed: 40109
# Total instructions executed: 28289
# CPI: 1.4178302520414294
# IPC: 0.7053030491909547
# Cycles per byte: 78.337890625
# DMA control cycles: 1230
#
# Results for output_files_c20p1305/1_2cores.txt:
# Total cycles elapsed: 68118
# Total instructions executed: 50601
# CPI: 1.3461789292701725
# IPC: 0.742843301330045
# Cycles per byte: 66.521484375
# DMA control cycles: 1804
#
# Results for output_files_c20p1305/2_2cores.txt:
# Total cycles elapsed: 124296
# Total instructions executed: 95226
# CPI: 1.3052737697687606
# IPC: 0.7661228036300444
# Cycles per byte: 60.69140625
# DMA control cycles: 3060
#
# Results for output_files_c20p1305/4_2cores.txt:
# Total cycles elapsed: 236312
# Total instructions executed: 184473
# CPI: 1.2810113133087226
# IPC: 0.7806332306442331
# Cycles per byte: 57.693359375
# DMA control cycles: 5324
#
# Results for output_files_c20p1305/8_2cores.txt:
# Total cycles elapsed: 460391
# Total instructions executed: 362969
# CPI: 1.2684030867649854
# IPC: 0.7883929095051815
# Cycles per byte: 56.2000732421875
# DMA control cycles: 9992
#
# Results for output_files_c20p1305/16_2cores.txt:
# Total cycles elapsed: 908804
# Total instructions executed: 719960
# CPI: 1.262297905439191
# IPC: 0.7922060202199814
# Cycles per byte: 55.468994140625
# DMA control cycles: 19338
#
# Results for output_files_c20p1305/32_2cores.txt:
# Total cycles elapsed: 1806110
# Total instructions executed: 1433944
# CPI: 1.2595401215110213
# IPC: 0.7939405684039178
# Cycles per byte: 55.11810302734375
# DMA control cycles: 38088
#
# Results for output_files_c20p1305/512_3cores.txt:
# Total cycles elapsed: 40511
# Total instructions executed: 31916
# CPI: 1.2693006642436395
# IPC: 0.7878354027301226
# Cycles per byte: 79.123046875
# DMA control cycles: 1084
#
# Results for output_files_c20p1305/1_3cores.txt:
# Total cycles elapsed: 69072
# Total instructions executed: 56185
# CPI: 1.2293672688439976
# IPC: 0.8134265693768821
# Cycles per byte: 67.453125
# DMA control cycles: 1570
#
# Results for output_files_c20p1305/2_3cores.txt:
# Total cycles elapsed: 115875
# Total instructions executed: 98445
# CPI: 1.1770531769008075
# IPC: 0.84957928802589
# Cycles per byte: 56.57958984375
# DMA control cycles: 2218
#
# Results for output_files_c20p1305/4_3cores.txt:
# Total cycles elapsed: 218773
# Total instructions executed: 189241
# CPI: 1.1560549775154432
# IPC: 0.8650107645824667
# Cycles per byte: 53.411376953125
# DMA control cycles: 4104
#
# Results for output_files_c20p1305/8_3cores.txt:
# Total cycles elapsed: 414452
# Total instructions executed: 364556
# CPI: 1.1368678611790781
# IPC: 0.8796097014853349
# Cycles per byte: 50.59228515625
# DMA control cycles: 7298
#
# Results for output_files_c20p1305/16_3cores.txt:
# Total cycles elapsed: 815731
# Total instructions executed: 721465
# CPI: 1.1306591449342658
# IPC: 0.8844398459786376
# Cycles per byte: 49.78826904296875
# DMA control cycles: 13840
#
# Results for output_files_c20p1305/32_3cores.txt:
# Total cycles elapsed: 1608908
# Total instructions executed: 1429004
# CPI: 1.1258946790911712
# IPC: 0.888182543688017
# Cycles per byte: 49.0999755859375
# DMA control cycles: 26884
#
# Results for output_files_c20p1305/512_4cores.txt:
# Total cycles elapsed: 35762
# Total instructions executed: 31373
# CPI: 1.1398973639753929
# IPC: 0.8772719646552206
# Cycles per byte: 69.84765625
# DMA control cycles: 920
#
# Results for output_files_c20p1305/1_4cores.txt:
# Total cycles elapsed: 59460
# Total instructions executed: 53439
# CPI: 1.1126705215292203
# IPC: 0.8987386478304743
# Cycles per byte: 58.06640625
# DMA control cycles: 1216
#
# Results for output_files_c20p1305/2_4cores.txt:
# Total cycles elapsed: 106058
# Total instructions executed: 97572
# CPI: 1.0869716722010412
# IPC: 0.9199871768277735
# Cycles per byte: 51.7861328125
# DMA control cycles: 1830
#
# Results for output_files_c20p1305/4_4cores.txt:
# Total cycles elapsed: 199745
# Total instructions executed: 185835
# CPI: 1.074851346624694
# IPC: 0.9303612105434429
# Cycles per byte: 48.765869140625
# DMA control cycles: 2942
#
# Results for output_files_c20p1305/8_4cores.txt:
# Total cycles elapsed: 387325
# Total instructions executed: 362363
# CPI: 1.0688867240860684
# IPC: 0.9355528303104628
# Cycles per byte: 47.2808837890625
# DMA control cycles: 5230
#
# Results for output_files_c20p1305/16_4cores.txt:
# Total cycles elapsed: 762361
# Total instructions executed: 715419
# CPI: 1.0656146957237647
# IPC: 0.9384254965823278
# Cycles per byte: 46.53082275390625
# DMA control cycles: 9806
#
# Results for output_files_c20p1305/32_4cores.txt:
# Total cycles elapsed: 1512996
# Total instructions executed: 1421531
# CPI: 1.0643425996337752
# IPC: 0.939547097282478
# Cycles per byte: 46.1729736328125
# DMA control cycles: 18938
#
# Results for output_files_c20p1305/512_5cores.txt:
# Total cycles elapsed: 40968
# Total instructions executed: 37163
# CPI: 1.1023867825525389
# IPC: 0.9071226322983792
# Cycles per byte: 80.015625
# DMA control cycles: 880
#
# Results for output_files_c20p1305/1_5cores.txt:
# Total cycles elapsed: 69810
# Total instructions executed: 63347
# CPI: 1.1020253524239507
# IPC: 0.9074201403810342
# Cycles per byte: 68.173828125
# DMA control cycles: 1194
#
# Results for output_files_c20p1305/2_5cores.txt:
# Total cycles elapsed: 112100
# Total instructions executed: 105340
# CPI: 1.0641731535978736
# IPC: 0.9396966993755576
# Cycles per byte: 54.736328125
# DMA control cycles: 1850
#
# Results for output_files_c20p1305/4_5cores.txt:
# Total cycles elapsed: 195839
# Total instructions executed: 189323
# CPI: 1.0344173713706206
# IPC: 0.9667277712815119
# Cycles per byte: 47.812255859375
# DMA control cycles: 2586
#
# Results for output_files_c20p1305/8_5cores.txt:
# Total cycles elapsed: 379087
# Total instructions executed: 367667
# CPI: 1.0310607152668039
# IPC: 0.9698749891185928
# Cycles per byte: 46.2752685546875
# DMA control cycles: 4478
#
# Results for output_files_c20p1305/16_5cores.txt:
# Total cycles elapsed: 746140
# Total instructions executed: 724355
# CPI: 1.0300750322700885
# IPC: 0.9708030664486558
# Cycles per byte: 45.540771484375
# DMA control cycles: 8276
#
# Results for output_files_c20p1305/32_5cores.txt:
# Total cycles elapsed: 1464597
# Total instructions executed: 1427355
# CPI: 1.0260916170118857
# IPC: 0.9745718446780923
# Cycles per byte: 44.695953369140625
# DMA control cycles: 15702
#
# Results for output_files_c20p1305/512_6cores.txt:
# Total cycles elapsed: 46149
# Total instructions executed: 42955
# CPI: 1.0743568851123269
# IPC: 0.9307893995536198
# Cycles per byte: 90.134765625
# DMA control cycles: 912
#
# Results for output_files_c20p1305/1_6cores.txt:
# Total cycles elapsed: 62227
# Total instructions executed: 60827
# CPI: 1.0230160948263107
# IPC: 0.9775017275459206
# Cycles per byte: 60.7685546875
# DMA control cycles: 1100
#
# Results for output_files_c20p1305/2_6cores.txt:
# Total cycles elapsed: 111995
# Total instructions executed: 109004
# CPI: 1.0274393600234855
# IPC: 0.9732934506004732
# Cycles per byte: 54.68505859375
# DMA control cycles: 1495
#
# Results for output_files_c20p1305/4_6cores.txt:
# Total cycles elapsed: 193154
# Total instructions executed: 192923
# CPI: 1.0011973688984726
# IPC: 0.998804063079201
# Cycles per byte: 47.15673828125
# DMA control cycles: 2284
#
# Results for output_files_c20p1305/8_6cores.txt:
# Total cycles elapsed: 373846
# Total instructions executed: 373195
# CPI: 1.0017443963611516
# IPC: 0.9982586412587001
# Cycles per byte: 45.635498046875
# DMA control cycles: 3912
#
# Results for output_files_c20p1305/16_6cores.txt:
# Total cycles elapsed: 717760
# Total instructions executed: 721307
# CPI: 0.9950825376711997
# IPC: 1.0049417632634865
# Cycles per byte: 43.80859375
# DMA control cycles: 7018
#
# Results for output_files_c20p1305/32_6cores.txt:
# Total cycles elapsed: 1423230
# Total instructions executed: 1429963
# CPI: 0.9952914865629391
# IPC: 1.0047307884178944
# Cycles per byte: 43.43353271484375
# DMA control cycles: 13384
#
# Results for output_files_c20p1305/512_7cores.txt:
# Total cycles elapsed: 51176
# Total instructions executed: 48703
# CPI: 1.050777159517894
# IPC: 0.9516765671408473
# Cycles per byte: 99.953125
# DMA control cycles: 971
#
# Results for output_files_c20p1305/1_7cores.txt:
# Total cycles elapsed: 69818
# Total instructions executed: 68611
# CPI: 1.0175919313229658
# IPC: 0.9827121945630066
# Cycles per byte: 68.181640625
# DMA control cycles: 1139
#
# Results for output_files_c20p1305/2_7cores.txt:
# Total cycles elapsed: 106940
# Total instructions executed: 108428
# CPI: 0.9862766075183532
# IPC: 1.0139143444922387
# Cycles per byte: 52.216796875
# DMA control cycles: 1443
#
# Results for output_files_c20p1305/4_7cores.txt:
# Total cycles elapsed: 201898
# Total instructions executed: 202535
# CPI: 0.9968548645913052
# IPC: 1.0031550584948836
# Cycles per byte: 49.29150390625
# DMA control cycles: 2623
#
# Results for output_files_c20p1305/8_7cores.txt:
# Total cycles elapsed: 370304
# Total instructions executed: 376275
# CPI: 0.9841312869576773
# IPC: 1.0161245895264432
# Cycles per byte: 45.203125
# DMA control cycles: 4025
#
# Results for output_files_c20p1305/16_7cores.txt:
# Total cycles elapsed: 707751
# Total instructions executed: 723755
# CPI: 0.9778875448183432
# IPC: 1.0226124724655987
# Cycles per byte: 43.19769287109375
# DMA control cycles: 6815
#
# Results for output_files_c20p1305/32_7cores.txt:
# Total cycles elapsed: 1402494
# Total instructions executed: 1433183
# CPI: 0.9785868238738528
# IPC: 1.0218817335403931
# Cycles per byte: 42.80072021484375
# DMA control cycles: 12286
#
# Results for output_files_c20p1305/512_8cores.txt:
# Total cycles elapsed: 32922
# Total instructions executed: 37907
# CPI: 0.8684939457092358
# IPC: 1.1514185043436
# Cycles per byte: 64.30078125
# DMA control cycles: 678
#
# Results for output_files_c20p1305/1_8cores.txt:
# Total cycles elapsed: 54204
# Total instructions executed: 59847
# CPI: 0.9057095593764098
# IPC: 1.1041067079920301
# Cycles per byte: 52.93359375
# DMA control cycles: 906
#
# Results for output_files_c20p1305/2_8cores.txt:
# Total cycles elapsed: 96763
# Total instructions executed: 103728
# CPI: 0.9328532315286133
# IPC: 1.0719799923524487
# Cycles per byte: 47.24755859375
# DMA control cycles: 1246
#
# Results for output_files_c20p1305/4_8cores.txt:
# Total cycles elapsed: 180605
# Total instructions executed: 191487
# CPI: 0.9431710768877261
# IPC: 1.0602530383987154
# Cycles per byte: 44.093017578125
# DMA control cycles: 1774
#
# Results for output_files_c20p1305/8_8cores.txt:
# Total cycles elapsed: 348783
# Total instructions executed: 367007
# CPI: 0.9503442713626715
# IPC: 1.052250253022653
# Cycles per byte: 42.5760498046875
# DMA control cycles: 2936
#
# Results for output_files_c20p1305/16_8cores.txt:
# Total cycles elapsed: 685260
# Total instructions executed: 718047
# CPI: 0.9543386435706854
# IPC: 1.047846073023378
# Cycles per byte: 41.824951171875
# DMA control cycles: 5258
#
# Results for output_files_c20p1305/32_8cores.txt:
# Total cycles elapsed: 1359193
# Total instructions executed: 1420127
# CPI: 0.957092569889876
# IPC: 1.0448310136970982
# Cycles per byte: 41.479278564453125
# DMA control cycles: 9902

# %%
# Size labels
sizes = ['512B', '1K', '2K', '4K', '8K', '16K', '32K']

# Function to plot the data
def plot_combined_data(clock_cycles, instruction_counts, cpis, ipcs, cpb, dma_cycles):
    # Plot clock cycles
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, clock_cycles[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Clock Cycles based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('Clock Cycles')
    plt.legend()
    plt.grid(True)
    plt.savefig('clock_cycles.png')
    plt.show()
    
    # Plot instruction counts
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, instruction_counts[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Instruction Count based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('Instruction Count')
    plt.legend()
    plt.grid(True)
    plt.savefig('instruction_count.png')
    plt.show()
    
    # Plot CPI
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, cpis[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('CPI based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('CPI')
    plt.legend()
    plt.grid(True)
    plt.savefig('cpi.png')
    plt.show()
    
    # Plot IPC
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, ipcs[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('IPC based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('IPC')
    plt.legend()
    plt.grid(True)
    plt.savefig('ipc.png')
    plt.show()

    # Plot cycles per byte
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, cpb[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Cycles per Byte based on Payload Size')
    plt.xlabel('Payload Size (Bytes)')
    plt.ylabel('Cycles per Byte')
    plt.legend()
    plt.grid(True)
    plt.savefig('cycles_per_byte.png')
    plt.show()

    # Plot DMA cycles as a percentage of total cycles
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        dma_percentages = [100 * dma / total if total > 0 else 0 for dma, total in zip(dma_cycles[start_index:end_index], clock_cycles[start_index:end_index])]
        plt.plot(sizes, dma_percentages, marker='o', label=f'{core + 1} Core')
    plt.title('DMA Cycles as a Percentage of Total Cycles')
    plt.xlabel('Payload Size')
    plt.ylabel('DMA Cycles (%)')
    plt.legend()
    plt.grid(True)
    plt.savefig('dma_cycles.png')
    plt.show()

# %%
# Function to plot the speedup
def plot_speedup(clock_cycles):
    single_core_cycles = clock_cycles[:len(sizes)]
    
    plt.figure(figsize=(10, 6))
    for core in range(1, 8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        
        multi_core_cycles = clock_cycles[start_index:end_index]
        speedup = [single_core_cycles[i] / multi_core_cycles[i] for i in range(len(sizes))]
        
        plt.plot(sizes, speedup, marker='o', label=f'{core + 1} Cores')
    
    plt.title('Speedup Compared to 1 Core')
    plt.xlabel('Payload Size')
    plt.ylabel('Speedup')
    plt.legend()
    plt.grid(True)
    plt.savefig('speedup.png')
    plt.show()

# %%
# Function to plot the efficiency
def plot_efficiency(clock_cycles):
    single_core_cycles = clock_cycles[:len(sizes)]
    
    plt.figure(figsize=(10, 6))
    for core in range(1, 8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        
        multi_core_cycles = clock_cycles[start_index:end_index]
        efficiency = [single_core_cycles[i] / (multi_core_cycles[i] * (core + 1)) for i in range(len(sizes))]
        
        plt.plot(sizes, efficiency, marker='o', label=f'{core + 1} Cores')
    
    plt.title('Efficiency Compared to 1 Core')
    plt.xlabel('Payload Size')
    plt.ylabel('Efficiency')
    plt.legend()
    plt.grid(True)
    plt.savefig('efficiency.png')
    plt.show()

# %%
# Plot combined data
plot_combined_data(clock_cycles_list, instruction_count_list, cpi_list, ipc_list, cycles_per_byte_list, total_dma_to_cluster_cycles_list)
# Plot speedup
plot_speedup(clock_cycles_list)
# Plot efficiency
plot_efficiency(clock_cycles_list)
