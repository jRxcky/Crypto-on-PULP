# %%
import matplotlib.pyplot as plt

numbers_list = [512, 1, 2, 4, 8, 16, 32]
payload_sizes = [512, 1024, 2048, 4096, 8192, 16384, 32768]

def calculate_cpi(file_path, payload_size):
    # Initialize variables to store cycle numbers
    first_cycle = None
    last_cycle = None
    instruction_count = 0

    # Track cluster entry indices
    first_cluster_index = None
    last_cluster_index = None
    
    # Track dma wait control
    dma_wait_cycle = None
    cluster_or_dispatch_cycle = None
    total_dma_to_cluster_cycles = 0

    # Track dma control
    dma_cycle = None
    dma_stop_cycle = None

    # Read the contents of the file
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Identify the first and last cluster_entry
    for i, line in enumerate(lines):
        if "cluster_entry" in line:
            if first_cluster_index is None:
                first_cluster_index = i
            last_cluster_index = i

    # Loop through each line within the range of first and last cluster_entry
    if first_cluster_index is not None and last_cluster_index is not None:
        for line in lines[first_cluster_index:last_cluster_index+1]:
            parts = line.split(':')  # Split line by colon ':'
            if len(parts) >= 2:
                cycle_str = parts[1].strip()  # Extract the cycle number string
                try:
                    cycle_number = int(cycle_str)  # Convert the string to an integer
                    if first_cycle is None:
                        first_cycle = cycle_number
                    last_cycle = cycle_number
                    instruction_count += 1

                    # Check for "pi_cl_dma_cmd_wait"
                    if "pi_cl_dma_cmd_wait" in line and dma_wait_cycle is None:
                        dma_wait_cycle = cycle_number
                    # Check for "cluster_entry" or "eu_dispatch_team_config"
                    if ("cluster_entry" in line or "eu_dispatch_team_config" in line) and dma_wait_cycle is not None:
                        cluster_or_dispatch_cycle = cycle_number
                        total_dma_to_cluster_cycles += cluster_or_dispatch_cycle - dma_wait_cycle
                        dma_wait_cycle = None  # Reset for next pair

                    # Check for "pi_cl_dma_cmd"
                    if "pi_cl_dma_cmd:" in line and dma_cycle is None:
                        #print(f"dma {cycle_number}: {line.strip()}")  # Log the line for verification
                        dma_cycle = cycle_number
                    
                    # Check for "cluster_entry" or "eu_dispatch_team_config"
                    if ("cluster_entry" in line or "eu_dispatch_team_config" in line or "pi_cl_dma_cmd_wait" in line) and dma_cycle is not None:
                        #print(f"finish dma {cycle_number}: {line.strip()}")  # Log the line for verification
                        dma_stop_cycle = cycle_number
                        total_dma_to_cluster_cycles += dma_stop_cycle - dma_cycle
                        dma_cycle = None  # Reset for next pair

                        
                except ValueError:
                    continue  # Skip lines that cannot be converted to integers

    if first_cycle is not None and last_cycle is not None:
        total_cycles = last_cycle - first_cycle
        cpi = total_cycles / instruction_count if instruction_count > 0 else 0
        ipc = instruction_count / total_cycles if total_cycles > 0 else 0
        cycles_per_byte = total_cycles / payload_size if payload_size > 0 else 0
        return total_cycles, instruction_count, cpi, ipc, cycles_per_byte, total_dma_to_cluster_cycles
    else:
        return None, None, None, None, None

# %%
clock_cycles_list = []
instruction_count_list = []
cpi_list = []
ipc_list = []
cycles_per_byte_list = []
total_dma_to_cluster_cycles_list = []

for i in range(1, 9):
    for payload_size, number in zip(payload_sizes, numbers_list):
        file_path = f"output_files_c20/{number}_{i}cores.txt"
        total_cycles, instruction_count, cpi, ipc, cycles_per_byte, total_dma_to_cluster_cycles = calculate_cpi(file_path, payload_size)
        if total_cycles is not None and instruction_count is not None and cpi is not None and ipc is not None and cycles_per_byte is not None:
            print(f"Results for {file_path}:")
            print("Total cycles elapsed:", total_cycles)
            print("Total instructions executed:", instruction_count)
            print("CPI:", cpi)
            print("IPC:", ipc)
            print("Cycles per byte:", cycles_per_byte)
            print("DMA control cycles:", total_dma_to_cluster_cycles)
            print()
            clock_cycles_list.append(total_cycles)
            instruction_count_list.append(instruction_count)
            cpi_list.append(cpi)
            ipc_list.append(ipc)
            cycles_per_byte_list.append(cycles_per_byte)
            total_dma_to_cluster_cycles_list.append(total_dma_to_cluster_cycles)
        else:
            print(f"Error: Cycle numbers not found in the file {file_path}.")
# Out:
# Results for output_files_c20/512_1cores.txt:
# Total cycles elapsed: 28117
# Total instructions executed: 16646
# CPI: 1.6891145019824583
# IPC: 0.5920261763346019
# Cycles per byte: 54.916015625
# DMA control cycles: 1696
#
# Results for output_files_c20/1_1cores.txt:
# Total cycles elapsed: 50781
# Total instructions executed: 31310
# CPI: 1.621877994251038
# IPC: 0.616569189263701
# Cycles per byte: 49.5908203125
# DMA control cycles: 2858
#
# Results for output_files_c20/2_1cores.txt:
# Total cycles elapsed: 96485
# Total instructions executed: 60639
# CPI: 1.5911377166510001
# IPC: 0.6284811110535317
# Cycles per byte: 47.11181640625
# DMA control cycles: 5150
#
# Results for output_files_c20/4_1cores.txt:
# Total cycles elapsed: 186442
# Total instructions executed: 119295
# CPI: 1.5628651661846682
# IPC: 0.639850462878536
# Cycles per byte: 45.51806640625
# DMA control cycles: 9658
#
# Results for output_files_c20/8_1cores.txt:
# Total cycles elapsed: 367884
# Total instructions executed: 236607
# CPI: 1.5548314293321837
# IPC: 0.6431565384740843
# Cycles per byte: 44.90771484375
# DMA control cycles: 18812
#
# Results for output_files_c20/16_1cores.txt:
# Total cycles elapsed: 730519
# Total instructions executed: 471230
# CPI: 1.550238736922522
# IPC: 0.6450619354185175
# Cycles per byte: 44.58734130859375
# DMA control cycles: 37094
#
# Results for output_files_c20/32_1cores.txt:
# Total cycles elapsed: 1455852
# Total instructions executed: 940477
# CPI: 1.5479931991957272
# IPC: 0.6459976700928391
# Cycles per byte: 44.4290771484375
# DMA control cycles: 73690
#
# Results for output_files_c20/512_2cores.txt:
# Total cycles elapsed: 19221
# Total instructions executed: 17806
# CPI: 1.0794675951926318
# IPC: 0.9263826023619999
# Cycles per byte: 37.541015625
# DMA control cycles: 1074
#
# Results for output_files_c20/1_2cores.txt:
# Total cycles elapsed: 32964
# Total instructions executed: 31982
# CPI: 1.0307047714339317
# IPC: 0.9702099259798568
# Cycles per byte: 32.19140625
# DMA control cycles: 1644
#
# Results for output_files_c20/2_2cores.txt:
# Total cycles elapsed: 60348
# Total instructions executed: 60335
# CPI: 1.0002154636612248
# IPC: 0.9997845827533638
# Cycles per byte: 29.466796875
# DMA control cycles: 2808
#
# Results for output_files_c20/4_2cores.txt:
# Total cycles elapsed: 115033
# Total instructions executed: 117039
# CPI: 0.9828604140500176
# IPC: 1.0174384741769753
# Cycles per byte: 28.084228515625
# DMA control cycles: 4984
#
# Results for output_files_c20/8_2cores.txt:
# Total cycles elapsed: 224728
# Total instructions executed: 230447
# CPI: 0.9751830138817168
# IPC: 1.0254485422377273
# Cycles per byte: 27.4326171875
# DMA control cycles: 9480
#
# Results for output_files_c20/16_2cores.txt:
# Total cycles elapsed: 443803
# Total instructions executed: 457262
# CPI: 0.970566108707918
# IPC: 1.0303265187481834
# Cycles per byte: 27.08758544921875
# DMA control cycles: 18444
#
# Results for output_files_c20/32_2cores.txt:
# Total cycles elapsed: 882538
# Total instructions executed: 910894
# CPI: 0.9688701429584562
# IPC: 1.0321300612551527
# Cycles per byte: 26.93292236328125
# DMA control cycles: 36328
#
# Results for output_files_c20/512_3cores.txt:
# Total cycles elapsed: 18165
# Total instructions executed: 21195
# CPI: 0.8570417551309271
# IPC: 1.166804293971924
# Cycles per byte: 35.478515625
# DMA control cycles: 892
#
# Results for output_files_c20/1_3cores.txt:
# Total cycles elapsed: 30989
# Total instructions executed: 37112
# CPI: 0.8350129338219444
# IPC: 1.1975862402788087
# Cycles per byte: 30.2626953125
# DMA control cycles: 1316
#
# Results for output_files_c20/2_3cores.txt:
# Total cycles elapsed: 50608
# Total instructions executed: 63300
# CPI: 0.7994944707740916
# IPC: 1.2507903888713248
# Cycles per byte: 24.7109375
# DMA control cycles: 2022
#
# Results for output_files_c20/4_3cores.txt:
# Total cycles elapsed: 95858
# Total instructions executed: 121321
# CPI: 0.790118775809629
# IPC: 1.265632498070062
# Cycles per byte: 23.40283203125
# DMA control cycles: 3510
#
# Results for output_files_c20/8_3cores.txt:
# Total cycles elapsed: 180189
# Total instructions executed: 231716
# CPI: 0.7776286488632637
# IPC: 1.285960852216284
# Cycles per byte: 21.9957275390625
# DMA control cycles: 6434
#
# Results for output_files_c20/16_3cores.txt:
# Total cycles elapsed: 354980
# Total instructions executed: 458153
# CPI: 0.7748066693877372
# IPC: 1.2906445433545553
# Cycles per byte: 21.666259765625
# DMA control cycles: 12352
#
# Results for output_files_c20/32_3cores.txt:
# Total cycles elapsed: 698663
# Total instructions executed: 905380
# CPI: 0.7716792948817072
# IPC: 1.2958751214820308
# Cycles per byte: 21.321502685546875
# DMA control cycles: 24078
#
# Results for output_files_c20/512_4cores.txt:
# Total cycles elapsed: 14872
# Total instructions executed: 20858
# CPI: 0.7130117940358616
# IPC: 1.402501344809037
# Cycles per byte: 29.046875
# DMA control cycles: 796
#
# Results for output_files_c20/1_4cores.txt:
# Total cycles elapsed: 24405
# Total instructions executed: 34792
# CPI: 0.7014543573235227
# IPC: 1.4256095062487195
# Cycles per byte: 23.8330078125
# DMA control cycles: 1080
#
# Results for output_files_c20/2_4cores.txt:
# Total cycles elapsed: 42980
# Total instructions executed: 62661
# CPI: 0.6859130878856067
# IPC: 1.457910656119125
# Cycles per byte: 20.986328125
# DMA control cycles: 1672
#
# Results for output_files_c20/4_4cores.txt:
# Total cycles elapsed: 80495
# Total instructions executed: 118397
# CPI: 0.6798736454470975
# IPC: 1.4708615441952917
# Cycles per byte: 19.652099609375
# DMA control cycles: 2798
#
# Results for output_files_c20/8_4cores.txt:
# Total cycles elapsed: 155490
# Total instructions executed: 229869
# CPI: 0.6764287485480861
# IPC: 1.478352305614509
# Cycles per byte: 18.980712890625
# DMA control cycles: 5064
#
# Results for output_files_c20/16_4cores.txt:
# Total cycles elapsed: 304915
# Total instructions executed: 452813
# CPI: 0.6733795186975639
# IPC: 1.4850466523457357
# Cycles per byte: 18.61053466796875
# DMA control cycles: 9578
#
# Results for output_files_c20/32_4cores.txt:
# Total cycles elapsed: 604435
# Total instructions executed: 898701
# CPI: 0.6725651801878489
# IPC: 1.4868447393019928
# Cycles per byte: 18.445892333984375
# DMA control cycles: 18614
#
# Results for output_files_c20/512_5cores.txt:
# Total cycles elapsed: 17427
# Total instructions executed: 26198
# CPI: 0.6652034506450875
# IPC: 1.5032994778217708
# Cycles per byte: 34.037109375
# DMA control cycles: 776
#
# Results for output_files_c20/1_5cores.txt:
# Total cycles elapsed: 29574
# Total instructions executed: 43822
# CPI: 0.6748665054082424
# IPC: 1.4817745316832354
# Cycles per byte: 28.880859375
# DMA control cycles: 1070
#
# Results for output_files_c20/2_5cores.txt:
# Total cycles elapsed: 44756
# Total instructions executed: 69747
# CPI: 0.6416906820365034
# IPC: 1.5583832335329342
# Cycles per byte: 21.853515625
# DMA control cycles: 1490
#
# Results for output_files_c20/4_5cores.txt:
# Total cycles elapsed: 75282
# Total instructions executed: 121595
# CPI: 0.6191208520087175
# IPC: 1.6151935389601764
# Cycles per byte: 18.37939453125
# DMA control cycles: 2410
#
# Results for output_files_c20/8_5cores.txt:
# Total cycles elapsed: 145042
# Total instructions executed: 234615
# CPI: 0.6182128167423225
# IPC: 1.617565946415521
# Cycles per byte: 17.705322265625
# DMA control cycles: 4296
#
# Results for output_files_c20/16_5cores.txt:
# Total cycles elapsed: 284615
# Total instructions executed: 460655
# CPI: 0.6178484983338941
# IPC: 1.6185197547564254
# Cycles per byte: 17.37152099609375
# DMA control cycles: 8050
#
# Results for output_files_c20/32_5cores.txt:
# Total cycles elapsed: 554974
# Total instructions executed: 903411
# CPI: 0.6143095446037297
# IPC: 1.6278438269180178
# Cycles per byte: 16.93646240234375
# DMA control cycles: 15442
#
# Results for output_files_c20/512_6cores.txt:
# Total cycles elapsed: 20231
# Total instructions executed: 31544
# CPI: 0.6413581029672838
# IPC: 1.5591913400227373
# Cycles per byte: 39.513671875
# DMA control cycles: 792
#
# Results for output_files_c20/1_6cores.txt:
# Total cycles elapsed: 24799
# Total instructions executed: 41690
# CPI: 0.5948428879827297
# IPC: 1.6811161740392757
# Cycles per byte: 24.2177734375
# DMA control cycles: 932
#
# Results for output_files_c20/2_6cores.txt:
# Total cycles elapsed: 44105
# Total instructions executed: 73153
# CPI: 0.6029144395991962
# IPC: 1.6586101349053395
# Cycles per byte: 21.53564453125
# DMA control cycles: 1371
#
# Results for output_files_c20/4_6cores.txt:
# Total cycles elapsed: 72482
# Total instructions executed: 124907
# CPI: 0.5802877340741511
# IPC: 1.7232830219916668
# Cycles per byte: 17.69580078125
# DMA control cycles: 2084
#
# Results for output_files_c20/8_6cores.txt:
# Total cycles elapsed: 139069
# Total instructions executed: 239585
# CPI: 0.5804578750756516
# IPC: 1.722777901617183
# Cycles per byte: 16.9761962890625
# DMA control cycles: 3662
#
# Results for output_files_c20/16_6cores.txt:
# Total cycles elapsed: 262196
# Total instructions executed: 457771
# CPI: 0.5727667327113338
# IPC: 1.745911455552335
# Cycles per byte: 16.003173828125
# DMA control cycles: 6682
#
# Results for output_files_c20/32_6cores.txt:
# Total cycles elapsed: 518526
# Total instructions executed: 905313
# CPI: 0.5727588138025191
# IPC: 1.7459355943578527
# Cycles per byte: 15.82415771484375
# DMA control cycles: 12856
#
# Results for output_files_c20/512_7cores.txt:
# Total cycles elapsed: 22959
# Total instructions executed: 36863
# CPI: 0.6228196294387326
# IPC: 1.6056012892547584
# Cycles per byte: 44.841796875
# DMA control cycles: 805
#
# Results for output_files_c20/1_7cores.txt:
# Total cycles elapsed: 28731
# Total instructions executed: 48843
# CPI: 0.5882316811006695
# IPC: 1.7000104416831994
# Cycles per byte: 28.0576171875
# DMA control cycles: 947
#
# Results for output_files_c20/2_7cores.txt:
# Total cycles elapsed: 40384
# Total instructions executed: 72804
# CPI: 0.5546947969891765
# IPC: 1.8027931854199684
# Cycles per byte: 19.71875
# DMA control cycles: 1227
#
# Results for output_files_c20/4_7cores.txt:
# Total cycles elapsed: 75123
# Total instructions executed: 133719
# CPI: 0.5617975007291409
# IPC: 1.7800007986901483
# Cycles per byte: 18.340576171875
# DMA control cycles: 1906
#
# Results for output_files_c20/8_7cores.txt:
# Total cycles elapsed: 133256
# Total instructions executed: 242563
# CPI: 0.5493665563173279
# IPC: 1.820278261391607
# Cycles per byte: 16.2666015625
# DMA control cycles: 3200
#
# Results for output_files_c20/16_7cores.txt:
# Total cycles elapsed: 249427
# Total instructions executed: 460251
# CPI: 0.5419368996482354
# IPC: 1.8452332746655333
# Cycles per byte: 15.22381591796875
# DMA control cycles: 5794
#
# Results for output_files_c20/32_7cores.txt:
# Total cycles elapsed: 492801
# Total instructions executed: 908631
# CPI: 0.5423554776361361
# IPC: 1.8438091643482866
# Cycles per byte: 15.039093017578125
# DMA control cycles: 11116
#
# Results for output_files_c20/512_8cores.txt:
# Total cycles elapsed: 12777
# Total instructions executed: 27331
# CPI: 0.4674911272913541
# IPC: 2.1390780308366595
# Cycles per byte: 24.955078125
# DMA control cycles: 607
#
# Results for output_files_c20/1_8cores.txt:
# Total cycles elapsed: 20057
# Total instructions executed: 41141
# CPI: 0.48751853382270727
# IPC: 2.0512040684050454
# Cycles per byte: 19.5869140625
# DMA control cycles: 829
#
# Results for output_files_c20/2_8cores.txt:
# Total cycles elapsed: 34450
# Total instructions executed: 68762
# CPI: 0.5010034612140426
# IPC: 1.9959941944847606
# Cycles per byte: 16.8212890625
# DMA control cycles: 1117
#
# Results for output_files_c20/4_8cores.txt:
# Total cycles elapsed: 62818
# Total instructions executed: 124002
# CPI: 0.5065886034096224
# IPC: 1.9739883472889936
# Cycles per byte: 15.33642578125
# DMA control cycles: 1639
#
# Results for output_files_c20/8_8cores.txt:
# Total cycles elapsed: 120014
# Total instructions executed: 234482
# CPI: 0.5118260676725719
# IPC: 1.953788724648791
# Cycles per byte: 14.650146484375
# DMA control cycles: 2763
#
# Results for output_files_c20/16_8cores.txt:
# Total cycles elapsed: 234226
# Total instructions executed: 455442
# CPI: 0.51428282854897
# IPC: 1.9444553550844057
# Cycles per byte: 14.2960205078125
# DMA control cycles: 5001
#
# Results for output_files_c20/32_8cores.txt:
# Total cycles elapsed: 462418
# Total instructions executed: 897362
# CPI: 0.5153082033783467
# IPC: 1.9405862228546467
# Cycles per byte: 14.11187744140625
# DMA control cycles: 9477

# %%
# Size labels
sizes = ['512B', '1K', '2K', '4K', '8K', '16K', '32K']

# Function to plot the data
def plot_combined_data(clock_cycles, instruction_counts, cpis, ipcs, cpb, dma_cycles):
    # Plot clock cycles
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, clock_cycles[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Clock Cycles based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('Clock Cycles')
    plt.legend()
    plt.grid(True)
    plt.savefig('clock_cycles.png')
    plt.show()
    
    # Plot instruction counts
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, instruction_counts[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Instruction Count based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('Instruction Count')
    plt.legend()
    plt.grid(True)
    plt.savefig('instruction_count.png')
    plt.show()
    
    # Plot CPI
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, cpis[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('CPI based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('CPI')
    plt.legend()
    plt.grid(True)
    plt.savefig('cpi.png')
    plt.show()
    
    # Plot IPC
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, ipcs[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('IPC based on Payload Size')
    plt.xlabel('Payload Size')
    plt.ylabel('IPC')
    plt.legend()
    plt.grid(True)
    plt.savefig('ipc.png')
    plt.show()

    # Plot cycles per byte
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        plt.plot(sizes, cpb[start_index:end_index], marker='o', label=f'{core + 1} Core')
    plt.title('Cycles per Byte based on Payload Size')
    plt.xlabel('Payload Size (Bytes)')
    plt.ylabel('Cycles per Byte')
    plt.legend()
    plt.grid(True)
    plt.savefig('cycles_per_byte.png')
    plt.show()

    # Plot DMA cycles as a percentage of total cycles
    plt.figure(figsize=(10, 6))
    for core in range(8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        dma_percentages = [100 * dma / total if total > 0 else 0 for dma, total in zip(dma_cycles[start_index:end_index], clock_cycles[start_index:end_index])]
        plt.plot(sizes, dma_percentages, marker='o', label=f'{core + 1} Core')
    plt.title('DMA Cycles as a Percentage of Total Cycles')
    plt.xlabel('Payload Size')
    plt.ylabel('DMA Cycles (%)')
    plt.legend()
    plt.grid(True)
    plt.savefig('dma_cycles.png')
    plt.show()

# %%
# Function to plot the speedup
def plot_speedup(clock_cycles):
    single_core_cycles = clock_cycles[:len(sizes)]
    
    plt.figure(figsize=(10, 6))
    for core in range(1, 8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        
        multi_core_cycles = clock_cycles[start_index:end_index]
        speedup = [single_core_cycles[i] / multi_core_cycles[i] for i in range(len(sizes))]
        
        plt.plot(sizes, speedup, marker='o', label=f'{core + 1} Cores')
    
    plt.title('Speedup Compared to 1 Core')
    plt.xlabel('Payload Size')
    plt.ylabel('Speedup')
    plt.legend()
    plt.grid(True)
    plt.savefig('speedup.png')
    plt.show()

# %%
# Function to plot the efficiency
def plot_efficiency(clock_cycles):
    single_core_cycles = clock_cycles[:len(sizes)]
    
    plt.figure(figsize=(10, 6))
    for core in range(1, 8):
        start_index = core * len(sizes)
        end_index = (core + 1) * len(sizes)
        
        multi_core_cycles = clock_cycles[start_index:end_index]
        efficiency = [single_core_cycles[i] / (multi_core_cycles[i] * (core + 1)) for i in range(len(sizes))]
        
        plt.plot(sizes, efficiency, marker='o', label=f'{core + 1} Cores')
    
    plt.title('Efficiency Compared to 1 Core')
    plt.xlabel('Payload Size')
    plt.ylabel('Efficiency')
    plt.legend()
    plt.grid(True)
    plt.savefig('efficiency.png')
    plt.show()

# %%
# Plot combined data
plot_combined_data(clock_cycles_list, instruction_count_list, cpi_list, ipc_list, cycles_per_byte_list, total_dma_to_cluster_cycles_list)
# Plot speedup
plot_speedup(clock_cycles_list)
# Plot efficiency
plot_efficiency(clock_cycles_list)
